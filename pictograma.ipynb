# %% [markdown]
# # Se diseña el pictograma como imágen en el siguiente link.
# - https://drive.google.com/file/d/1K7ne_M64q6Fa0r1h4VcNJBRL1LmlhcPG/view?usp=drive_link
# - Al abrir hay que seleccionar abrir con draw.io. Para lo cuál es necesario previamente haber vinculado una cuenta de google a draw.io, posterior a esto debería aparecer el siguiente ícono.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1 Armado de diagrama pictorial inicial
# https://drive.google.com/file/d/1K7ne_M64q6Fa0r1h4VcNJBRL1LmlhcPG/view?usp=sharing
# - Dejar anotado en el draw.io el nombre e información relevante. (ej. AWG de cables)
# - **IMPORTANTE** Dejar los datasheet por componentes utilizados.

# %% [markdown]
# ### 1.1 lista de componentes con infromación
# Pinout de pixhawk 6C: https://docs.holybro.com/autopilot/pixhawk-6c/pixhawk-6c-ports
#
# - ESC 4-in-1, para motores lifter: https://tmotorhobby.com/goods.php?id=821
# - Motores lifter, MN3510 Multirotor Fixed Wing UAV KV 700: https://cdn.robotshop.com/media/T/Tmo/RB-Tmo-201/pdf/ligpower_mn3510_kv700_high_performance_uav_motor_f_datasheet.pdf
# - 45A ESC BLHeli, para pusher: https://kamami.pl/en/brushless-motor-controllers-bldc/1181249-modesc45a-5906623471874.html
# - Motor pusher, GARTT ML 4108 620KV: https://es.aliexpress.com/i/4000583673818.html
# - Power module PM02: https://cdn.sparkfun.com/assets/8/1/d/b/7/Holybro_PM02D_Power_Module_Manual.pdf
# - GPS M9N: https://holybro.com/products/m9n-gps
# - Airspeed Sensor MS4525DO: https://docs.cirkitdesigner.com/component/1506f1d4-a7df-48f9-abdd-63536855b038/airspeed-sensor-ms4525do
# - Bandit Nano, comunicación por MLRS: https://cdn.shopify.com/s/files/1/0609/8324/7079/files/Bandit_NANO_67934ab7-9a99-44eb-8314-9ba0dfff145b.pdf?v=1737017377
#     - Caso 2, Bandit BR1, Módulo de receptor: https://cdn.shopify.com/s/files/1/0609/8324/7079/files/BR1_User_Manual.pdf?v=1722224113
#     - Caso 3, Radio SIK con receptor x8r: lol

# %% [markdown]
# ### 1.2 Alimentación de nano
# Es necesario darle alimentación directa al bandit (transmisión), falta investigar pero idea inicial en conectar a LiIo con tx30.

# %% [markdown]
# ### 1.3 Descripción de partes en diagrama
# Se pude poner una descripción en las imágenes, al apretar click derecho sobre la imagen o cable presionando "edit data".

# %% [markdown]
# ## ~~2 Modelo 3D del aeronave~~
# - Converitir los .stl a .step, Opciones: fusion360, online free converter, u otras opciones a encontrar.
# - Encontrar archivos cad de componentes:
#     - Autopiloto
#     - Motor lifter
#     - Motor pusher
# Se descarta el modelo 3D fiel del modelo dada la falta de capacidad de convertir .stl a .step. Se opta por la posibilidad de realizar scan 3D de la aeronave una vez construída.
